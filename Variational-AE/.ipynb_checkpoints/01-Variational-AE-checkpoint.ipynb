# %%
import torch
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Creating the Dataset

# %%
# square_size -> (min_size, max_size)

def generate_datapoint(size = (28, 28), square_size = (3, 7), grayscale = True):
    
    assert square_size[0] < size[0] and square_size[0] < size[1]
    assert square_size[1] < size[0] and square_size[1] < size[1]
    
    random_square_size = random.randint(*square_size)
    
    x_pos = random.randint(0, size[1] - random_square_size)
    y_pos = random.randint(0, size[0] - random_square_size)
    
    if grayscale:
        img = np.zeros(size)
        img[x_pos:x_pos + random_square_size, y_pos:y_pos + random_square_size] = 1.0
    else:
        img = np.zeros((3, *size))
        
        img[0,x_pos:x_pos + random_square_size, y_pos:y_pos + random_square_size] = random.random()
        img[1, x_pos:x_pos + random_square_size, y_pos:y_pos + random_square_size] = random.random()
        img[2, x_pos:x_pos + random_square_size, y_pos:y_pos + random_square_size] = random.random()
        
    
    return img, x_pos, y_pos, random_square_size


def generate_dataset(n = 3000, size = (28, 28), square_size = (3, 7), grayscale = True):
    x = []
    y = []
    
    for _ in range(n):
        img, x_pos, y_pos, spot_size = generate_datapoint(size, square_size, grayscale = grayscale)
        x.append(img)
        y.append([x_pos, y_pos, spot_size])
        
    return np.array(x), np.array(y)

# %% [markdown]
# # Define Autoencoder Model

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import torch
import torch.nn as nn

class Autoencoder(nn.Module):
    
    def __init__(self,
                 s,
                 data_channels = 1,
                 conv_feature_maps = 16,
                 kernel_size = 3,
                 stride_length = 1,
                 pool_size = 2,
                 fc_size = 256,
                 latent_size = 64
                ):
        super(Autoencoder, self).__init__()

        self.data_channels = data_channels
        self.conv_feature_maps = conv_feature_maps
        self.kernel_size = kernel_size
        self.stride_length = stride_length
        self.pool_size = pool_size
        self.fc_size = fc_size
        self.latent_size = latent_size
        
        
        
        self.is_log_mode = False
        
        conv2d_output_size = (s-kernel_size)//stride_length + 1
        pooling_output_size = conv2d_output_size//2
        deconv2d_output_size = (pooling_output_size - 1) * stride_length + kernel_size
        
        print(f"conv2d_output_size : {conv2d_output_size}")
        print(f"pooling_output_size : {pooling_output_size}")
        print(f"flatten_size : {conv_feature_maps * pooling_output_size * pooling_output_size}")
        
        self.encoder = nn.Sequential(
            nn.Conv2d(data_channels, conv_feature_maps, kernel_size, stride = stride_length),
            nn.BatchNorm2d(conv_feature_maps),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(pool_size, pool_size),
            
            nn.Flatten(),
            nn.Linear(conv_feature_maps * pooling_output_size * pooling_output_size, fc_size),
            nn.BatchNorm1d(fc_size),
            nn.LeakyReLU(inplace=True),
            
        )
        
        self.mean_encoder = nn.Linear(fc_size, latent_size)
        self.std_encoder = nn.Linear(fc_size, latent_size)
        
        self.decoder = nn.Sequential(
            nn.Linear(latent_size, fc_size),
            nn.BatchNorm1d(fc_size),
            nn.LeakyReLU(inplace=True),

            nn.Linear(fc_size, conv_feature_maps * pooling_output_size * pooling_output_size),
            nn.LeakyReLU(inplace=True),

            nn.Unflatten(1, (conv_feature_maps, pooling_output_size, pooling_output_size)),
            
            nn.ConvTranspose2d(conv_feature_maps, data_channels, kernel_size, stride = stride_length),
            nn.Upsample(scale_factor= s/deconv2d_output_size, mode='nearest'),
    
            nn.Sigmoid()
        )
                
    def forward(self, x):
    
        encoded = self.encoder(x)
        encoded_mean = self.mean_encoder(encoded)
        encoded_std = self.std_encoder(encoded)
        
        gaussian = torch.normal(0.0, 1.0, size=encoded_mean.shape)
        latent = encoded_mean + encoded_std * gaussian  # Reparametrization Trick
        
        decoded = self.decoder(latent)
        
        return decoded, latent
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='leaky_relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='leaky_relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
        
    def log_mode(self, val):
        assert type(val) == bool
        self.is_log_mode = val

# %%
s = 64
grayscale = True

X, y = generate_dataset(n = 3000, size = (s, s), square_size = (3, 16), grayscale = grayscale)
X_val, y_val = generate_dataset(n = 512, size = (s, s), square_size = (3, 16), grayscale = grayscale)

X.shape, X_val.shape
# Out:
# ((3000, 64, 64), (512, 64, 64))

# %%
ae_model = Autoencoder(s,
                       data_channels = 1 if grayscale else 3,
                       conv_feature_maps = 16,
                       stride_length = 2,
                       fc_size = 48,
                       latent_size = 16)
# Out:
# conv2d_output_size : 31
# pooling_output_size : 15
# flatten_size : 3600

# %%
ae_model
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=3600, out_features=48, bias=True)
#     (6): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (mean_encoder): Linear(in_features=48, out_features=16, bias=True)
#   (std_encoder): Linear(in_features=48, out_features=16, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=16, out_features=48, bias=True)
#     (1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): Linear(in_features=48, out_features=3600, bias=True)
#     (4): LeakyReLU(negative_slope=0.01, inplace=True)
#     (5): Unflatten(dim=1, unflattened_size=(16, 15, 15))
#     (6): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2))
#     (7): Upsample(scale_factor=2.064516129032258, mode=nearest)
#     (8): Sigmoid()
#   )
# )

# %%
ae_criterion = nn.MSELoss()
ae_optimizer = optim.NAdam(ae_model.parameters(), lr = 1e-4)

# %% [markdown]
# ## Train AE (grayscale)

# %%
batch_size = 32
n_train_batches = X.shape[0] // batch_size
n_val_batches = X_val.shape[0] // batch_size
n_epochs = 300
losses = []
val_losses = []

for epoch in range(n_epochs):
    
    ae_model.train()
    for batch_ind in range(n_train_batches):
        
        x = torch.Tensor(X[batch_ind * batch_size: (batch_ind + 1) * batch_size])
        x = x.unsqueeze(1) if grayscale else x
        reconstructed, _ = ae_model(x)
        loss = ae_criterion(reconstructed, x)

        
        ae_optimizer.zero_grad()
        loss.backward()
        ae_optimizer.step()
        
    losses.append(loss.item())
    
    ae_model.eval()
    with torch.no_grad():
        val_loss = torch.Tensor([0])
        for batch_ind in range(n_val_batches):
            x = torch.Tensor(X_val[batch_ind * batch_size : (batch_ind + 1) * batch_size])
            x = x.unsqueeze(1) if grayscale else x
            reconstructed, _ = ae_model(x)
            
            val_loss += ae_criterion(reconstructed, x)
            
        
        val_loss = val_loss.item() / n_val_batches
        val_losses.append(val_loss)
        print(f"Epoch : {epoch}/{n_epochs} \t loss = {losses[-1]:.5f} \t val_loss = {val_loss:.5f}")
# Out:
# Epoch : 0/300 	 loss = 0.23722 	 val_loss = 0.23839
# Epoch : 1/300 	 loss = 0.17033 	 val_loss = 0.17329
# Epoch : 2/300 	 loss = 0.10877 	 val_loss = 0.10954
# Epoch : 3/300 	 loss = 0.07040 	 val_loss = 0.07190
# Epoch : 4/300 	 loss = 0.04959 	 val_loss = 0.05157
# Epoch : 5/300 	 loss = 0.03916 	 val_loss = 0.04129
# Epoch : 6/300 	 loss = 0.03331 	 val_loss = 0.03574
# Epoch : 7/300 	 loss = 0.03114 	 val_loss = 0.03144
# Epoch : 8/300 	 loss = 0.02885 	 val_loss = 0.02945
# Epoch : 9/300 	 loss = 0.02764 	 val_loss = 0.02808
# Epoch : 10/300 	 loss = 0.02684 	 val_loss = 0.02706
# Epoch : 11/300 	 loss = 0.02611 	 val_loss = 0.02618
# Epoch : 12/300 	 loss = 0.02556 	 val_loss = 0.02546
# Epoch : 13/300 	 loss = 0.02492 	 val_loss = 0.02471
# Epoch : 14/300 	 loss = 0.02431 	 val_loss = 0.02411
# Epoch : 15/300 	 loss = 0.02377 	 val_loss = 0.02355
# Epoch : 16/300 	 loss = 0.02317 	 val_loss = 0.02283
# Epoch : 17/300 	 loss = 0.02241 	 val_loss = 0.02211
# Epoch : 18/300 	 loss = 0.02177 	 val_loss = 0.02144
# Epoch : 19/300 	 loss = 0.02112 	 val_loss = 0.02080
# Epoch : 20/300 	 loss = 0.02047 	 val_loss = 0.02013
# Epoch : 21/300 	 loss = 0.01977 	 val_loss = 0.01944
# Epoch : 22/300 	 loss = 0.01915 	 val_loss = 0.01881
# Epoch : 23/300 	 loss = 0.01848 	 val_loss = 0.01819
# Epoch : 24/300 	 loss = 0.01786 	 val_loss = 0.01762
# Epoch : 25/300 	 loss = 0.01727 	 val_loss = 0.01712
# Epoch : 26/300 	 loss = 0.01673 	 val_loss = 0.01662
# Epoch : 27/300 	 loss = 0.01627 	 val_loss = 0.01611
# Epoch : 28/300 	 loss = 0.01570 	 val_loss = 0.01564
# Epoch : 29/300 	 loss = 0.01523 	 val_loss = 0.01519
# Epoch : 30/300 	 loss = 0.01476 	 val_loss = 0.01481
# Epoch : 31/300 	 loss = 0.01431 	 val_loss = 0.01440
# Epoch : 32/300 	 loss = 0.01388 	 val_loss = 0.01402
# Epoch : 33/300 	 loss = 0.01352 	 val_loss = 0.01366
# Epoch : 34/300 	 loss = 0.01320 	 val_loss = 0.01330
# Epoch : 35/300 	 loss = 0.01278 	 val_loss = 0.01301
# Epoch : 36/300 	 loss = 0.01253 	 val_loss = 0.01266
# Epoch : 37/300 	 loss = 0.01212 	 val_loss = 0.01232
# Epoch : 38/300 	 loss = 0.01179 	 val_loss = 0.01209
# Epoch : 39/300 	 loss = 0.01154 	 val_loss = 0.01180
# Epoch : 40/300 	 loss = 0.01115 	 val_loss = 0.01142
# Epoch : 41/300 	 loss = 0.01090 	 val_loss = 0.01111
# Epoch : 42/300 	 loss = 0.01058 	 val_loss = 0.01081
# Epoch : 43/300 	 loss = 0.01037 	 val_loss = 0.01068
# Epoch : 44/300 	 loss = 0.01007 	 val_loss = 0.01029
# Epoch : 45/300 	 loss = 0.00980 	 val_loss = 0.01007
# Epoch : 46/300 	 loss = 0.00950 	 val_loss = 0.00988
# Epoch : 47/300 	 loss = 0.00937 	 val_loss = 0.00959
# Epoch : 48/300 	 loss = 0.00901 	 val_loss = 0.00934
# Epoch : 49/300 	 loss = 0.00876 	 val_loss = 0.00908
# Epoch : 50/300 	 loss = 0.00846 	 val_loss = 0.00882
# Epoch : 51/300 	 loss = 0.00824 	 val_loss = 0.00863
# Epoch : 52/300 	 loss = 0.00810 	 val_loss = 0.00842
# Epoch : 53/300 	 loss = 0.00787 	 val_loss = 0.00827
# Epoch : 54/300 	 loss = 0.00764 	 val_loss = 0.00806
# Epoch : 55/300 	 loss = 0.00748 	 val_loss = 0.00794
# Epoch : 56/300 	 loss = 0.00739 	 val_loss = 0.00784
# Epoch : 57/300 	 loss = 0.00718 	 val_loss = 0.00762
# Epoch : 58/300 	 loss = 0.00702 	 val_loss = 0.00750
# Epoch : 59/300 	 loss = 0.00682 	 val_loss = 0.00732
# Epoch : 60/300 	 loss = 0.00666 	 val_loss = 0.00724
# Epoch : 61/300 	 loss = 0.00656 	 val_loss = 0.00718
# Epoch : 62/300 	 loss = 0.00638 	 val_loss = 0.00703
# Epoch : 63/300 	 loss = 0.00624 	 val_loss = 0.00695
# Epoch : 64/300 	 loss = 0.00611 	 val_loss = 0.00689
# Epoch : 65/300 	 loss = 0.00603 	 val_loss = 0.00671
# Epoch : 66/300 	 loss = 0.00586 	 val_loss = 0.00675
# Epoch : 67/300 	 loss = 0.00575 	 val_loss = 0.00656
# Epoch : 68/300 	 loss = 0.00568 	 val_loss = 0.00647
# Epoch : 69/300 	 loss = 0.00558 	 val_loss = 0.00639
# Epoch : 70/300 	 loss = 0.00549 	 val_loss = 0.00637
# Epoch : 71/300 	 loss = 0.00538 	 val_loss = 0.00632
# Epoch : 72/300 	 loss = 0.00533 	 val_loss = 0.00627
# Epoch : 73/300 	 loss = 0.00527 	 val_loss = 0.00623
# Epoch : 74/300 	 loss = 0.00508 	 val_loss = 0.00615
# Epoch : 75/300 	 loss = 0.00516 	 val_loss = 0.00611
# Epoch : 76/300 	 loss = 0.00504 	 val_loss = 0.00612
# Epoch : 77/300 	 loss = 0.00497 	 val_loss = 0.00597
# Epoch : 78/300 	 loss = 0.00487 	 val_loss = 0.00591
# Epoch : 79/300 	 loss = 0.00483 	 val_loss = 0.00593
# Epoch : 80/300 	 loss = 0.00482 	 val_loss = 0.00596
# Epoch : 81/300 	 loss = 0.00476 	 val_loss = 0.00586
# Epoch : 82/300 	 loss = 0.00466 	 val_loss = 0.00590
# Epoch : 83/300 	 loss = 0.00454 	 val_loss = 0.00579
# Epoch : 84/300 	 loss = 0.00453 	 val_loss = 0.00575
# Epoch : 85/300 	 loss = 0.00446 	 val_loss = 0.00574
# Epoch : 86/300 	 loss = 0.00445 	 val_loss = 0.00572
# Epoch : 87/300 	 loss = 0.00441 	 val_loss = 0.00561
# Epoch : 88/300 	 loss = 0.00431 	 val_loss = 0.00569
# Epoch : 89/300 	 loss = 0.00445 	 val_loss = 0.00561
# Epoch : 90/300 	 loss = 0.00427 	 val_loss = 0.00556
# Epoch : 91/300 	 loss = 0.00423 	 val_loss = 0.00555
# Epoch : 92/300 	 loss = 0.00419 	 val_loss = 0.00557
# Epoch : 93/300 	 loss = 0.00418 	 val_loss = 0.00554
# Epoch : 94/300 	 loss = 0.00416 	 val_loss = 0.00548
# Epoch : 95/300 	 loss = 0.00411 	 val_loss = 0.00554
# Epoch : 96/300 	 loss = 0.00408 	 val_loss = 0.00542
# Epoch : 97/300 	 loss = 0.00399 	 val_loss = 0.00554
# Epoch : 98/300 	 loss = 0.00406 	 val_loss = 0.00547
# Epoch : 99/300 	 loss = 0.00402 	 val_loss = 0.00543
# Epoch : 100/300 	 loss = 0.00391 	 val_loss = 0.00544
# Epoch : 101/300 	 loss = 0.00396 	 val_loss = 0.00534
# Epoch : 102/300 	 loss = 0.00391 	 val_loss = 0.00534
# Epoch : 103/300 	 loss = 0.00389 	 val_loss = 0.00541
# Epoch : 104/300 	 loss = 0.00392 	 val_loss = 0.00540
# Epoch : 105/300 	 loss = 0.00382 	 val_loss = 0.00538
# Epoch : 106/300 	 loss = 0.00384 	 val_loss = 0.00534
# Epoch : 107/300 	 loss = 0.00383 	 val_loss = 0.00532
# Epoch : 108/300 	 loss = 0.00378 	 val_loss = 0.00532
# Epoch : 109/300 	 loss = 0.00372 	 val_loss = 0.00534
# Epoch : 110/300 	 loss = 0.00372 	 val_loss = 0.00526
# Epoch : 111/300 	 loss = 0.00375 	 val_loss = 0.00533
# Epoch : 112/300 	 loss = 0.00365 	 val_loss = 0.00530
# Epoch : 113/300 	 loss = 0.00366 	 val_loss = 0.00529
# Epoch : 114/300 	 loss = 0.00365 	 val_loss = 0.00525
# Epoch : 115/300 	 loss = 0.00365 	 val_loss = 0.00531
# Epoch : 116/300 	 loss = 0.00360 	 val_loss = 0.00523
# Epoch : 117/300 	 loss = 0.00360 	 val_loss = 0.00528
# Epoch : 118/300 	 loss = 0.00356 	 val_loss = 0.00523
# Epoch : 119/300 	 loss = 0.00359 	 val_loss = 0.00522
# Epoch : 120/300 	 loss = 0.00357 	 val_loss = 0.00523
# Epoch : 121/300 	 loss = 0.00353 	 val_loss = 0.00519
# Epoch : 122/300 	 loss = 0.00352 	 val_loss = 0.00516
# Epoch : 123/300 	 loss = 0.00348 	 val_loss = 0.00527
# Epoch : 124/300 	 loss = 0.00349 	 val_loss = 0.00523
# Epoch : 125/300 	 loss = 0.00348 	 val_loss = 0.00521
# Epoch : 126/300 	 loss = 0.00345 	 val_loss = 0.00522
# Epoch : 127/300 	 loss = 0.00340 	 val_loss = 0.00521
# Epoch : 128/300 	 loss = 0.00345 	 val_loss = 0.00518
# Epoch : 129/300 	 loss = 0.00343 	 val_loss = 0.00513
# Epoch : 130/300 	 loss = 0.00339 	 val_loss = 0.00523
# Epoch : 131/300 	 loss = 0.00338 	 val_loss = 0.00512
# Epoch : 132/300 	 loss = 0.00340 	 val_loss = 0.00521
# Epoch : 133/300 	 loss = 0.00337 	 val_loss = 0.00524
# Epoch : 134/300 	 loss = 0.00333 	 val_loss = 0.00524
# Epoch : 135/300 	 loss = 0.00331 	 val_loss = 0.00516
# Epoch : 136/300 	 loss = 0.00332 	 val_loss = 0.00521
# Epoch : 137/300 	 loss = 0.00331 	 val_loss = 0.00517
# Epoch : 138/300 	 loss = 0.00331 	 val_loss = 0.00513
# Epoch : 139/300 	 loss = 0.00334 	 val_loss = 0.00520
# Epoch : 140/300 	 loss = 0.00329 	 val_loss = 0.00513
# Epoch : 141/300 	 loss = 0.00328 	 val_loss = 0.00520
# Epoch : 142/300 	 loss = 0.00327 	 val_loss = 0.00516
# Epoch : 143/300 	 loss = 0.00327 	 val_loss = 0.00510
# Epoch : 144/300 	 loss = 0.00327 	 val_loss = 0.00511
# Epoch : 145/300 	 loss = 0.00323 	 val_loss = 0.00515
# Epoch : 146/300 	 loss = 0.00324 	 val_loss = 0.00518
# Epoch : 147/300 	 loss = 0.00330 	 val_loss = 0.00513
# Epoch : 148/300 	 loss = 0.00320 	 val_loss = 0.00513
# Epoch : 149/300 	 loss = 0.00320 	 val_loss = 0.00514
# Epoch : 150/300 	 loss = 0.00321 	 val_loss = 0.00517
# Epoch : 151/300 	 loss = 0.00323 	 val_loss = 0.00520
# Epoch : 152/300 	 loss = 0.00320 	 val_loss = 0.00513
# Epoch : 153/300 	 loss = 0.00317 	 val_loss = 0.00506
# Epoch : 154/300 	 loss = 0.00315 	 val_loss = 0.00513
# Epoch : 155/300 	 loss = 0.00317 	 val_loss = 0.00511
# Epoch : 156/300 	 loss = 0.00315 	 val_loss = 0.00518
# Epoch : 157/300 	 loss = 0.00319 	 val_loss = 0.00509
# Epoch : 158/300 	 loss = 0.00316 	 val_loss = 0.00510
# Epoch : 159/300 	 loss = 0.00313 	 val_loss = 0.00508
# Epoch : 160/300 	 loss = 0.00315 	 val_loss = 0.00516
# Epoch : 161/300 	 loss = 0.00316 	 val_loss = 0.00509
# Epoch : 162/300 	 loss = 0.00310 	 val_loss = 0.00512
# Epoch : 163/300 	 loss = 0.00311 	 val_loss = 0.00514
# Epoch : 164/300 	 loss = 0.00314 	 val_loss = 0.00515
# Epoch : 165/300 	 loss = 0.00316 	 val_loss = 0.00511
# Epoch : 166/300 	 loss = 0.00312 	 val_loss = 0.00512
# Epoch : 167/300 	 loss = 0.00312 	 val_loss = 0.00509
# Epoch : 168/300 	 loss = 0.00310 	 val_loss = 0.00510
# Epoch : 169/300 	 loss = 0.00310 	 val_loss = 0.00506
# Epoch : 170/300 	 loss = 0.00309 	 val_loss = 0.00507
# Epoch : 171/300 	 loss = 0.00313 	 val_loss = 0.00512
# Epoch : 172/300 	 loss = 0.00313 	 val_loss = 0.00507
# Epoch : 173/300 	 loss = 0.00311 	 val_loss = 0.00512
# Epoch : 174/300 	 loss = 0.00311 	 val_loss = 0.00511
# Epoch : 175/300 	 loss = 0.00304 	 val_loss = 0.00506
# Epoch : 176/300 	 loss = 0.00307 	 val_loss = 0.00508
# Epoch : 177/300 	 loss = 0.00300 	 val_loss = 0.00501
# Epoch : 178/300 	 loss = 0.00305 	 val_loss = 0.00503
# Epoch : 179/300 	 loss = 0.00305 	 val_loss = 0.00501
# Epoch : 180/300 	 loss = 0.00307 	 val_loss = 0.00512
# Epoch : 181/300 	 loss = 0.00302 	 val_loss = 0.00508
# Epoch : 182/300 	 loss = 0.00306 	 val_loss = 0.00506
# Epoch : 183/300 	 loss = 0.00303 	 val_loss = 0.00500
# Epoch : 184/300 	 loss = 0.00303 	 val_loss = 0.00503
# Epoch : 185/300 	 loss = 0.00304 	 val_loss = 0.00502
# Epoch : 186/300 	 loss = 0.00303 	 val_loss = 0.00503
# Epoch : 187/300 	 loss = 0.00300 	 val_loss = 0.00505
# Epoch : 188/300 	 loss = 0.00299 	 val_loss = 0.00511
# Epoch : 189/300 	 loss = 0.00301 	 val_loss = 0.00511
# Epoch : 190/300 	 loss = 0.00302 	 val_loss = 0.00505
# Epoch : 191/300 	 loss = 0.00302 	 val_loss = 0.00507
# Epoch : 192/300 	 loss = 0.00299 	 val_loss = 0.00501
# Epoch : 193/300 	 loss = 0.00299 	 val_loss = 0.00506
# Epoch : 194/300 	 loss = 0.00297 	 val_loss = 0.00506
# Epoch : 195/300 	 loss = 0.00300 	 val_loss = 0.00508
# Epoch : 196/300 	 loss = 0.00300 	 val_loss = 0.00503
# Epoch : 197/300 	 loss = 0.00301 	 val_loss = 0.00503
# Epoch : 198/300 	 loss = 0.00297 	 val_loss = 0.00506
# Epoch : 199/300 	 loss = 0.00300 	 val_loss = 0.00504
# Epoch : 200/300 	 loss = 0.00296 	 val_loss = 0.00501
# Epoch : 201/300 	 loss = 0.00296 	 val_loss = 0.00501
# Epoch : 202/300 	 loss = 0.00296 	 val_loss = 0.00500
# Epoch : 203/300 	 loss = 0.00295 	 val_loss = 0.00502
# Epoch : 204/300 	 loss = 0.00295 	 val_loss = 0.00508
# Epoch : 205/300 	 loss = 0.00294 	 val_loss = 0.00506
# Epoch : 206/300 	 loss = 0.00295 	 val_loss = 0.00501
# Epoch : 207/300 	 loss = 0.00298 	 val_loss = 0.00499
# Epoch : 208/300 	 loss = 0.00296 	 val_loss = 0.00501
# Epoch : 209/300 	 loss = 0.00294 	 val_loss = 0.00503
# Epoch : 210/300 	 loss = 0.00292 	 val_loss = 0.00499
# Epoch : 211/300 	 loss = 0.00293 	 val_loss = 0.00503
# Epoch : 212/300 	 loss = 0.00295 	 val_loss = 0.00501
# Epoch : 213/300 	 loss = 0.00294 	 val_loss = 0.00503
# Epoch : 214/300 	 loss = 0.00295 	 val_loss = 0.00500
# Epoch : 215/300 	 loss = 0.00294 	 val_loss = 0.00502
# Epoch : 216/300 	 loss = 0.00291 	 val_loss = 0.00503
# Epoch : 217/300 	 loss = 0.00291 	 val_loss = 0.00503
# Epoch : 218/300 	 loss = 0.00293 	 val_loss = 0.00503
# Epoch : 219/300 	 loss = 0.00291 	 val_loss = 0.00501
# Epoch : 220/300 	 loss = 0.00296 	 val_loss = 0.00500
# Epoch : 221/300 	 loss = 0.00292 	 val_loss = 0.00499
# Epoch : 222/300 	 loss = 0.00292 	 val_loss = 0.00505
# Epoch : 223/300 	 loss = 0.00293 	 val_loss = 0.00501
# Epoch : 224/300 	 loss = 0.00293 	 val_loss = 0.00503
# Epoch : 225/300 	 loss = 0.00291 	 val_loss = 0.00500
# Epoch : 271/300 	 loss = 0.00282 	 val_loss = 0.00498
# Epoch : 272/300 	 loss = 0.00283 	 val_loss = 0.00498
# Epoch : 273/300 	 loss = 0.00282 	 val_loss = 0.00500
# Epoch : 274/300 	 loss = 0.00284 	 val_loss = 0.00495
# Epoch : 275/300 	 loss = 0.00284 	 val_loss = 0.00493
# Epoch : 276/300 	 loss = 0.00284 	 val_loss = 0.00499
# Epoch : 277/300 	 loss = 0.00284 	 val_loss = 0.00500
# Epoch : 278/300 	 loss = 0.00282 	 val_loss = 0.00496
# Epoch : 279/300 	 loss = 0.00281 	 val_loss = 0.00503
# Epoch : 280/300 	 loss = 0.00284 	 val_loss = 0.00497
# Epoch : 281/300 	 loss = 0.00281 	 val_loss = 0.00498
# Epoch : 282/300 	 loss = 0.00280 	 val_loss = 0.00500
# Epoch : 283/300 	 loss = 0.00285 	 val_loss = 0.00495
# Epoch : 284/300 	 loss = 0.00279 	 val_loss = 0.00495
# Epoch : 285/300 	 loss = 0.00279 	 val_loss = 0.00499
# Epoch : 286/300 	 loss = 0.00278 	 val_loss = 0.00499
# Epoch : 287/300 	 loss = 0.00279 	 val_loss = 0.00496
# Epoch : 288/300 	 loss = 0.00280 	 val_loss = 0.00497
# Epoch : 289/300 	 loss = 0.00278 	 val_loss = 0.00499
# Epoch : 290/300 	 loss = 0.00280 	 val_loss = 0.00495
# Epoch : 291/300 	 loss = 0.00283 	 val_loss = 0.00495
# Epoch : 292/300 	 loss = 0.00280 	 val_loss = 0.00493
# Epoch : 293/300 	 loss = 0.00284 	 val_loss = 0.00493
# Epoch : 294/300 	 loss = 0.00280 	 val_loss = 0.00498
# Epoch : 295/300 	 loss = 0.00278 	 val_loss = 0.00499
# Epoch : 296/300 	 loss = 0.00280 	 val_loss = 0.00495
# Epoch : 297/300 	 loss = 0.00279 	 val_loss = 0.00492
# Epoch : 298/300 	 loss = 0.00279 	 val_loss = 0.00497
# Epoch : 299/300 	 loss = 0.00279 	 val_loss = 0.00499

# %%
plt.plot(losses)
plt.plot(val_losses)

plt.show()

# %%
ae_model.eval()
_x = torch.Tensor(X_val[random.randint(0, X_val.shape[0])]).unsqueeze(0)
_x = _x.unsqueeze(1) if grayscale else _x
_recon, latent = ae_model(_x)

img = np.array(_x.squeeze().detach().numpy())
recon_img = _recon.squeeze().detach().numpy()

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

axes[0].imshow(img.T, cmap = 'gray' if grayscale else None)
axes[1].imshow(recon_img.T, cmap = 'gray' if grayscale else None)

plt.show()

# %% [markdown]
# ## Train AE (RGB)

# %%
s = 64
grayscale = False

X, y = generate_dataset(n = 3000, size = (s, s), square_size = (3, 16), grayscale = grayscale)
X_val, y_val = generate_dataset(n = 512, size = (s, s), square_size = (3, 16), grayscale = grayscale)

# %%
ae_model = Autoencoder(s,
                       data_channels = 1 if grayscale else 3,
                       conv_feature_maps = 32,
                       stride_length = 1,
                       fc_size = 64,
                       latent_size = 16)
# Out:
# conv2d_output_size : 62
# pooling_output_size : 31
# flatten_size : 30752

# %%
ae_criterion = nn.MSELoss()
ae_optimizer = optim.NAdam(ae_model.parameters(), lr = 1e-4)

# %%
batch_size = 32
n_train_batches = X.shape[0] // batch_size
n_val_batches = X_val.shape[0] // batch_size
n_epochs = 500
losses = []
val_losses = []

for epoch in range(n_epochs):
    
    ae_model.train()
    for batch_ind in range(n_train_batches):
        
        x = torch.Tensor(X[batch_ind * batch_size: (batch_ind + 1) * batch_size])
        x = x.unsqueeze(1) if grayscale else x
        reconstructed, _ = ae_model(x)
        loss = ae_criterion(reconstructed, x)

        
        ae_optimizer.zero_grad()
        loss.backward()
        ae_optimizer.step()
        
    losses.append(loss.item())
    
    ae_model.eval()
    with torch.no_grad():
        val_loss = torch.Tensor([0])
        for batch_ind in range(n_val_batches):
            x = torch.Tensor(X_val[batch_ind * batch_size : (batch_ind + 1) * batch_size])
            x = x.unsqueeze(1) if grayscale else x
            reconstructed, _ = ae_model(x)
            
            val_loss += ae_criterion(reconstructed, x)
            
        
        val_loss = val_loss.item() / n_val_batches
        val_losses.append(val_loss)
        print(f"Epoch : {epoch}/{n_epochs} \t loss = {losses[-1]:.5f} \t val_loss = {val_loss:.5f}")
# Out:
# Epoch : 0/500 	 loss = 0.09941 	 val_loss = 0.09709
# Epoch : 1/500 	 loss = 0.03541 	 val_loss = 0.03552
# Epoch : 2/500 	 loss = 0.02072 	 val_loss = 0.01906
# Epoch : 3/500 	 loss = 0.01586 	 val_loss = 0.01422
# Epoch : 4/500 	 loss = 0.01411 	 val_loss = 0.01144
# Epoch : 5/500 	 loss = 0.01316 	 val_loss = 0.01035
# Epoch : 6/500 	 loss = 0.01264 	 val_loss = 0.00971
# Epoch : 7/500 	 loss = 0.01216 	 val_loss = 0.00928
# Epoch : 8/500 	 loss = 0.01199 	 val_loss = 0.00895
# Epoch : 9/500 	 loss = 0.01151 	 val_loss = 0.00867
# Epoch : 10/500 	 loss = 0.01119 	 val_loss = 0.00839
# Epoch : 11/500 	 loss = 0.01084 	 val_loss = 0.00814
# Epoch : 12/500 	 loss = 0.01045 	 val_loss = 0.00784
# Epoch : 13/500 	 loss = 0.00996 	 val_loss = 0.00754
# Epoch : 14/500 	 loss = 0.00957 	 val_loss = 0.00730
# Epoch : 15/500 	 loss = 0.00926 	 val_loss = 0.00698
# Epoch : 16/500 	 loss = 0.00878 	 val_loss = 0.00672
# Epoch : 17/500 	 loss = 0.00847 	 val_loss = 0.00643
# Epoch : 18/500 	 loss = 0.00810 	 val_loss = 0.00618
# Epoch : 19/500 	 loss = 0.00779 	 val_loss = 0.00596
# Epoch : 20/500 	 loss = 0.00750 	 val_loss = 0.00574
# Epoch : 21/500 	 loss = 0.00728 	 val_loss = 0.00553
# Epoch : 22/500 	 loss = 0.00707 	 val_loss = 0.00535
# Epoch : 23/500 	 loss = 0.00685 	 val_loss = 0.00517
# Epoch : 24/500 	 loss = 0.00676 	 val_loss = 0.00508
# Epoch : 25/500 	 loss = 0.00649 	 val_loss = 0.00494
# Epoch : 26/500 	 loss = 0.00640 	 val_loss = 0.00484
# Epoch : 72/500 	 loss = 0.00327 	 val_loss = 0.00296
# Epoch : 73/500 	 loss = 0.00320 	 val_loss = 0.00293
# Epoch : 74/500 	 loss = 0.00316 	 val_loss = 0.00288
# Epoch : 75/500 	 loss = 0.00300 	 val_loss = 0.00285
# Epoch : 76/500 	 loss = 0.00296 	 val_loss = 0.00283
# Epoch : 77/500 	 loss = 0.00287 	 val_loss = 0.00284
# Epoch : 78/500 	 loss = 0.00286 	 val_loss = 0.00280
# Epoch : 79/500 	 loss = 0.00278 	 val_loss = 0.00280
# Epoch : 80/500 	 loss = 0.00272 	 val_loss = 0.00279
# Epoch : 81/500 	 loss = 0.00264 	 val_loss = 0.00273
# Epoch : 82/500 	 loss = 0.00260 	 val_loss = 0.00273
# Epoch : 83/500 	 loss = 0.00257 	 val_loss = 0.00273
# Epoch : 84/500 	 loss = 0.00250 	 val_loss = 0.00273
# Epoch : 85/500 	 loss = 0.00244 	 val_loss = 0.00268
# Epoch : 86/500 	 loss = 0.00245 	 val_loss = 0.00267
# Epoch : 87/500 	 loss = 0.00242 	 val_loss = 0.00267
# Epoch : 88/500 	 loss = 0.00236 	 val_loss = 0.00266
# Epoch : 89/500 	 loss = 0.00228 	 val_loss = 0.00260
# Epoch : 90/500 	 loss = 0.00228 	 val_loss = 0.00260
# Epoch : 91/500 	 loss = 0.00223 	 val_loss = 0.00261
# Epoch : 92/500 	 loss = 0.00220 	 val_loss = 0.00261
# Epoch : 93/500 	 loss = 0.00221 	 val_loss = 0.00260
# Epoch : 94/500 	 loss = 0.00222 	 val_loss = 0.00260
# Epoch : 95/500 	 loss = 0.00213 	 val_loss = 0.00259
# Epoch : 96/500 	 loss = 0.00210 	 val_loss = 0.00255
# Epoch : 97/500 	 loss = 0.00209 	 val_loss = 0.00259
# Epoch : 98/500 	 loss = 0.00206 	 val_loss = 0.00252
# Epoch : 99/500 	 loss = 0.00203 	 val_loss = 0.00258
# Epoch : 100/500 	 loss = 0.00205 	 val_loss = 0.00255
# Epoch : 101/500 	 loss = 0.00202 	 val_loss = 0.00255
# Epoch : 102/500 	 loss = 0.00200 	 val_loss = 0.00255
# Epoch : 103/500 	 loss = 0.00194 	 val_loss = 0.00257
# Epoch : 104/500 	 loss = 0.00196 	 val_loss = 0.00256
# Epoch : 105/500 	 loss = 0.00192 	 val_loss = 0.00255
# Epoch : 106/500 	 loss = 0.00190 	 val_loss = 0.00253
# Epoch : 107/500 	 loss = 0.00187 	 val_loss = 0.00246
# Epoch : 108/500 	 loss = 0.00188 	 val_loss = 0.00253
# Epoch : 109/500 	 loss = 0.00183 	 val_loss = 0.00255
# Epoch : 110/500 	 loss = 0.00184 	 val_loss = 0.00252
# Epoch : 111/500 	 loss = 0.00184 	 val_loss = 0.00252
# Epoch : 112/500 	 loss = 0.00185 	 val_loss = 0.00254
# Epoch : 113/500 	 loss = 0.00180 	 val_loss = 0.00247
# Epoch : 114/500 	 loss = 0.00178 	 val_loss = 0.00252
# Epoch : 115/500 	 loss = 0.00176 	 val_loss = 0.00248
# Epoch : 161/500 	 loss = 0.00137 	 val_loss = 0.00240
# Epoch : 162/500 	 loss = 0.00136 	 val_loss = 0.00241
# Epoch : 163/500 	 loss = 0.00137 	 val_loss = 0.00243
# Epoch : 164/500 	 loss = 0.00135 	 val_loss = 0.00245
# Epoch : 165/500 	 loss = 0.00132 	 val_loss = 0.00247
# Epoch : 166/500 	 loss = 0.00132 	 val_loss = 0.00246
# Epoch : 167/500 	 loss = 0.00132 	 val_loss = 0.00248
# Epoch : 168/500 	 loss = 0.00131 	 val_loss = 0.00243
# Epoch : 169/500 	 loss = 0.00132 	 val_loss = 0.00241
# Epoch : 170/500 	 loss = 0.00130 	 val_loss = 0.00245
# Epoch : 171/500 	 loss = 0.00130 	 val_loss = 0.00240
# Epoch : 172/500 	 loss = 0.00130 	 val_loss = 0.00241
# Epoch : 173/500 	 loss = 0.00129 	 val_loss = 0.00242
# Epoch : 174/500 	 loss = 0.00133 	 val_loss = 0.00244
# Epoch : 175/500 	 loss = 0.00133 	 val_loss = 0.00245
# Epoch : 176/500 	 loss = 0.00128 	 val_loss = 0.00243
# Epoch : 177/500 	 loss = 0.00128 	 val_loss = 0.00242
# Epoch : 178/500 	 loss = 0.00128 	 val_loss = 0.00240
# Epoch : 179/500 	 loss = 0.00128 	 val_loss = 0.00239
# Epoch : 180/500 	 loss = 0.00129 	 val_loss = 0.00242
# Epoch : 181/500 	 loss = 0.00128 	 val_loss = 0.00239
# Epoch : 182/500 	 loss = 0.00127 	 val_loss = 0.00240
# Epoch : 183/500 	 loss = 0.00128 	 val_loss = 0.00237
# Epoch : 184/500 	 loss = 0.00127 	 val_loss = 0.00242
# Epoch : 185/500 	 loss = 0.00126 	 val_loss = 0.00242
# Epoch : 186/500 	 loss = 0.00125 	 val_loss = 0.00244
# Epoch : 187/500 	 loss = 0.00127 	 val_loss = 0.00240
# Epoch : 188/500 	 loss = 0.00127 	 val_loss = 0.00241
# Epoch : 189/500 	 loss = 0.00125 	 val_loss = 0.00239
# Epoch : 190/500 	 loss = 0.00127 	 val_loss = 0.00242
# Epoch : 191/500 	 loss = 0.00123 	 val_loss = 0.00242
# Epoch : 192/500 	 loss = 0.00123 	 val_loss = 0.00239
# Epoch : 193/500 	 loss = 0.00123 	 val_loss = 0.00242
# Epoch : 194/500 	 loss = 0.00122 	 val_loss = 0.00241
# Epoch : 195/500 	 loss = 0.00122 	 val_loss = 0.00240
# Epoch : 196/500 	 loss = 0.00121 	 val_loss = 0.00244
# Epoch : 197/500 	 loss = 0.00124 	 val_loss = 0.00241
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 21
#      19     ae_optimizer.zero_grad()
#      20     loss.backward()
# ---> 21     ae_optimizer.step()
#      23 losses.append(loss.item())
#      25 ae_model.eval()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\nadam.py:135, in NAdam.step(self, closure)
#     132             mu_products.append(state['mu_product'])
#     133             state_steps.append(state['step'])
# --> 135     nadam(params_with_grad,
#     136           grads,
#     137           exp_avgs,
#     138           exp_avg_sqs,
#     139           mu_products,
#     140           state_steps,
#     141           beta1=beta1,
#     142           beta2=beta2,
#     143           lr=group['lr'],
#     144           weight_decay=group['weight_decay'],
#     145           momentum_decay=group['momentum_decay'],
#     146           eps=group['eps'],
#     147           foreach=group['foreach'])
#     149 return loss
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\nadam.py:191, in nadam(params, grads, exp_avgs, exp_avg_sqs, mu_products, state_steps, foreach, beta1, beta2, lr, weight_decay, momentum_decay, eps)
#     188 else:
#     189     func = _single_tensor_nadam
# --> 191 func(params,
#     192      grads,
#     193      exp_avgs,
#     194      exp_avg_sqs,
#     195      mu_products,
#     196      state_steps,
#     197      beta1=beta1,
#     198      beta2=beta2,
#     199      lr=lr,
#     200      weight_decay=weight_decay,
#     201      momentum_decay=momentum_decay,
#     202      eps=eps)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\nadam.py:244, in _single_tensor_nadam(params, grads, exp_avgs, exp_avg_sqs, mu_products, state_steps, beta1, beta2, lr, weight_decay, momentum_decay, eps)
#     242 # decay the first and second moment running average coefficient
#     243 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 244 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     246 denom = exp_avg_sq.div(bias_correction2).sqrt().add_(eps)
#     247 param.addcdiv_(grad, denom, value=-lr * (1. - mu) / (1. - mu_product.item()))
#
# KeyboardInterrupt:

# %%
plt.plot(losses)
plt.plot(val_losses)

plt.show()

# %%
ae_model.eval()
_x = torch.Tensor(generate_datapoint(size=(64, 64), square_size=(3, 16), grayscale=False)[0]).unsqueeze(0)
_x = _x.unsqueeze(1) if grayscale else _x
_recon, latent = ae_model(_x)

img = np.array(_x.squeeze().detach().numpy())
recon_img = _recon.squeeze().detach().numpy()

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

axes[0].imshow(img.T, cmap = 'gray' if grayscale else None)
axes[1].imshow(recon_img.T, cmap = 'gray' if grayscale else None)

plt.show()

# %%
ae_model.eval()
_x = torch.Tensor(generate_datapoint(size=(64, 64), square_size=(3, 16), grayscale=False)[0]).unsqueeze(0)
_x = _x.unsqueeze(1) if grayscale else _x
_recon, latent = ae_model(_x)

img = np.array(_x.squeeze().detach().numpy())
recon_img = _recon.squeeze().detach().numpy()

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

axes[0].imshow(img.T, cmap = 'gray' if grayscale else None)
axes[1].imshow(recon_img.T, cmap = 'gray' if grayscale else None)

plt.show()

# %% [markdown]
# ## Scratch Area

# %%
t = torch.Tensor(np.random.uniform(size = 10))
np.random.normal(loc = 0.0, scale = 1.0, size = t.shape)
# Out:
# array([ 0.26575543, -1.44246235, -0.60449388, -0.137419  , -0.71990778,
#         1.22155549,  0.16220391,  1.17225455, -0.02004255, -0.90040949])

# %%
t = torch.Tensor(np.random.uniform(size = 10))
t
# Out:
# tensor([0.5393, 0.3538, 0.9235, 0.5542, 0.0764, 0.6695, 0.2911, 0.5484, 0.8297,
#         0.6306])

# %%
gaussian = torch.normal(0.0, 1.0, size = t.shape)
gaussian
# Out:
# tensor([ 0.6148, -1.0794, -0.7928, -1.4567, -0.6297, -1.9706, -2.8048, -0.3812,
#          0.1286,  0.9690])

# %%
t * gaussian
# Out:
# tensor([ 0.3315, -0.3819, -0.7322, -0.8073, -0.0481, -1.3194, -0.8164, -0.2090,
#          0.1067,  0.6111])

# %%
# Out:
# 0.33156164
